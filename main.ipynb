# %% [markdown]
# # BISINDO RGB-to-Skeleton Pipeline
# Notebook ini dikonfigurasi untuk dijalankan di Google Colab. Hasil ekstraksi (pickle dan excel) akan otomatis tersimpan ke dalam folder `data/` di repositori ini, yang berada di Google Drive Anda.

# %%
# 1. Hubungkan (Mount) Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Pindah ke direktori proyek (Sesuaikan path ini dengan lokasi folder project Anda di Drive)
import os

# GANTI PATH DI BAWAH JIKA FOLDER PROJECT BERBEDA
project_path = '/content/drive/MyDrive/TA/Source-Code/BISINDO_PROJECT/rgb-to-skeleton-mediapipe' 

if os.path.exists(project_path):
    os.chdir(project_path)
    print("Current working directory:", os.getcwd())
else:
    print("Path tidak ditemukan. Harap pastikan project_path sudah benar.")

# %%
# 3. Install semua dependencies yang dibutuhkan
# !pip install -r requirements.txt

# %%
# 4. Jalankan Pipeline untuk mengekstrak keypoints
# Ganti '--input' dengan path folder video raw Anda yang ada di Google Drive.
# File pickle akan otomatis tersimpan di dalam folder 'data/pickle/' di dalam project_path.
# !python main.py --input data/raw/ --pickle-name pose_bisindo
